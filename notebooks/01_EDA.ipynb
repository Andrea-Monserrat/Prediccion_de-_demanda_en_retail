# %% [markdown]
# ## Exploración y entendimiento profundo de los datos ##

# %% [markdown]
# Librerias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Datos:

# %%
PATH = "../data/raw/"

item_categories = pd.read_csv(PATH + "item_categories.csv", encoding='utf-8', low_memory=False)
items= pd.read_csv(PATH + "items.csv", encoding='utf-8', low_memory=False)
sales_train = pd.read_csv(PATH + "sales_train.csv", encoding='utf-8', low_memory=False)
sample_submission = pd.read_csv(PATH + "sample_submission.csv", encoding='utf-8', low_memory=False)
shops = pd.read_csv(PATH + "shops.csv", encoding='utf-8', low_memory=False)
test = pd.read_csv(PATH + "test.csv", encoding='utf-8', low_memory=False)

# %% [markdown]
# Vista sencilla de tablas:

# %%
item_categories.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     str
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), str(1)
# memory usage: 1.4 KB

# %%
sample_submission.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              214200 non-null  int64
#  1   item_cnt_month  214200 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 MB

# %%
shops.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     str
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), str(1)
# memory usage: 1.1 KB

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB

# %% [markdown]
# *Combinaciones producto-tienda para predicción*

# %%
test.head(3)
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233

# %% [markdown]
# *Información de productos y categorías*

# %%
items.head(3)
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
#
#    item_category_id
# 0                40
# 1                76
# 2                40

# %% [markdown]
# **Exploración sobre datos históricos de ventas diarias (2013-2015)**
#
# - Como parte del análisis de datos, haremos enfasís en esta tabla pues tiene dos de las columnas clave para validar nuestro modelo: shop_id e item_id.

# %%
sales_train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %% [markdown]
# - Areás de oportunidad identificadas: precios negativos
# - item_cnt_day negativos, (se sugiere devoluciones)

# %%
sales_train.head(3)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2552       899.0           1.0
# 2  05.01.2013               0       25     2552       899.0          -1.0

# %% [markdown]
# Area de oportunidad identiifcada: date y su formato

# %%
print(len(sales_train))
# Out:
# 2935849

# %% [markdown]
# Trabajaremos en estos primeros cambios de formato y limpieza de datos:

# %%
#copia de datos
sales = sales_train.copy()

# Fecha a datetime (en este dataset viene como "dd.mm.yyyy")
sales["date"] = pd.to_datetime(sales["date"], format="%d.%m.%Y", errors="coerce")
print("Rango fechas:", sales["date"].min(), "→", sales["date"].max())
# Out:
# Rango fechas: 2013-01-01 00:00:00 → 2015-10-31 00:00:00

# %%
#filtrado de precios negativos y devoluciones
sales = sales[(sales["item_price"] > 0) & (sales["item_cnt_day"] >= 0)].copy()
print("Filas después de limpiar:", len(sales))
print("Se eliminaron el " , (1-((len(sales)/len(sales_train))*1)),  "%")
# Out:
# Filas después de limpiar: 2928492
# Se eliminaron el  0.002505919071450924 %

# %% [markdown]
# Una vez con estos primeros cambios, se propone crear nuevas columnas:
#
# - "revenue_day": identifica los montos diarios generado por producto

# %%
# Ingreso diario
sales["revenue_day"] = sales["item_price"] * sales["item_cnt_day"]
sales["revenue_day"].describe()
# Out:
# count    2.928492e+06
# mean     1.164373e+03
# std      5.687671e+03
# min      7.000000e-02
# 25%      2.490000e+02
# 50%      4.490000e+02
# 75%      1.090000e+03
# max      1.829990e+06
# Name: revenue_day, dtype: float64

# %% [markdown]
# Objetivo
#
# - item_cnt_month = suma de item_cnt_day por (date_block_num, shop_id, item_id)
#
# Predictoras base
#
# - Identificadores: shop_id, item_id, date_block_num (mes)
# - Precio: item_price
# - Info del producto: item_category_id
# - Info de tienda: shop_name

# %% [markdown]
# Tabla mensual con grid

# %% [markdown]
# ¿Cuánto se vende de cada producto por tienda (vista mensual)?

# %%
#groupby mensual
monthly_sales = (
    sales.groupby(["date_block_num", "shop_id", "item_id"], as_index=False)
    .agg(
        item_cnt_month=("item_cnt_day", "sum"),     # target
        item_price_mean=("item_price", "mean"),
        revenue_month=("revenue_day", "sum"),
        days_obs=("date", "nunique"),
    )
)

# 2) Grid mensual: todos los pares (shop_id, item_id) que existieron en ese mes
monthly_pairs = sales[["date_block_num", "shop_id", "item_id"]].drop_duplicates()

#Merge para meter ceros donde no hubo venta
monthly = monthly_pairs.merge(
    monthly_sales,
    on=["date_block_num", "shop_id", "item_id"],
    how="left"
)

monthly["item_cnt_month"] = monthly["item_cnt_month"].fillna(0).astype(np.float32)
monthly["item_price_mean"] = monthly["item_price_mean"].fillna(0).astype(np.float32)
monthly["revenue_month"] = monthly["revenue_month"].fillna(0).astype(np.float32)
monthly["days_obs"] = monthly["days_obs"].fillna(0).astype(np.int16)

monthly = monthly.merge(items[["item_id", "item_category_id"]], on="item_id", how="left")

print("Shape monthly:", monthly.shape)
print("Proporción de ceros:", (monthly["item_cnt_month"] == 0).mean().round(4))
monthly.head()
# Out:
# Shape monthly: (1608226, 8)
# Proporción de ceros: 0.0
#    date_block_num  shop_id  item_id  item_cnt_month  item_price_mean  \
# 0               0       59    22154             1.0       999.000000
# 1               0       25     2552             1.0       899.000000
# 2               0       25     2554             1.0      1709.050049
# 3               0       25     2555             1.0      1099.000000
# 4               0       25     2564             1.0       349.000000
#
#    revenue_month  days_obs  item_category_id
# 0     999.000000         1                37
# 1     899.000000         1                58
# 2    1709.050049         1                58
# 3    1099.000000         1                56
# 4     349.000000         1                59

# %% [markdown]
# *¿Por qué es importante agrupar por tienda - producto?:*
# - lo que buscamos es identificar la relación que pueda existir entre los productos que son vendidos según su ubicación, de esta manera podemos generar hipotesis o generar nuevas variables.

# %% [markdown]
# ¿La distribucción de unidades vendidas por tienda es la misma o existen diferencias?

# %%
shops_item = (
    monthly.groupby("shop_id")["item_cnt_month"].sum()
    .sort_values(ascending=False)
)

print ("Promedio de unidades vendidas por tienda:", shops_item.mean())


plt.bar(shops_item.index, shops_item.values)
plt.xlabel("shop_id")
plt.ylabel("Total item_cnt_month")
plt.show()
# Out:
# Promedio de unidades vendidas por tienda: 60929.1

# %% [markdown]
# Observamos que notablemente existen tiendas donde las ventas son mayores al promedio de ventas por tienda.
# Ahora, quisieramos validar si en las tiendas donde se vende más productos, se tiene la misma distribucción de productos en ventas.
#
# Se establece una nueva columna para clasificar según el número total de ventas por mes, de tal manera que tendremos tiendas:
#
# - pequeñas
# - promedio
# - grandes

# %%
p33 = shops_item.quantile(0.33)
p66 = shops_item.quantile(0.66)

small_shops = shops_item[shops_item <= p33].index.tolist()
average_shops = shops_item[
    (shops_item > p33) & (shops_item <= p66)
].index.tolist()
large_shops = shops_item[shops_item > p66].index.tolist()

# %%
shop_category = {}

for s in small_shops:
    shop_category[s] = "small"

for s in average_shops:
    shop_category[s] = "average"

for s in large_shops:
    shop_category[s] = "large"

monthly["shop_size"] = monthly["shop_id"].map(shop_category)

# %%
monthly.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month',
#        'item_price_mean', 'revenue_month', 'days_obs', 'item_category_id',
#        'shop_size'],
#       dtype='str')

# %% [markdown]
# Comparativa de distribución de ingresos por tamaño de tienda:

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=monthly, x='shop_size', y='revenue_month')
plt.title('Distribución de revenue mensual por tamaño de tienda')
#plt.yscale('log') 
plt.show()

# %% [markdown]
# Evolución temporal por tamaño:

# %%
df_time = (
    monthly.groupby(['date_block_num', 'shop_size'])['revenue_month']
      .mean()
      .reset_index()
)

plt.figure(figsize=(10,5))
sns.lineplot(data=df_time, x='date_block_num', y='revenue_month', hue='shop_size')
plt.title('Tendencia de revenue por tamaño de tienda')
plt.show()

# %% [markdown]
# ¿quién dómina el negocio?

# %%
share = (
    monthly.groupby('shop_size')['revenue_month']
      .sum()
      .reset_index()
)

share['share'] = share['revenue_month'] / share['revenue_month'].sum()

plt.figure(figsize=(6,4))
sns.barplot(data=share, x='shop_size', y='share')
plt.title('Participación del revenue por tamaño de tienda')
plt.show()

# %% [markdown]
# ¿quién dómina el negocio?

# %%
df_item = (
    monthly.groupby(['shop_size', 'shop_id'])['revenue_month']
      .mean()
      .reset_index()
)

plt.figure(figsize=(8,5))
sns.boxplot(data=df_item, x='shop_size', y='revenue_month')
plt.title('Revenue promedio por tienda según tamaño')
plt.show()

# %% [markdown]
# ¿Ciertas categorías funcionan mejor en tiendas grandes?

# %%
pivot = (
    monthly.groupby(['shop_size', 'item_category_id'])['revenue_month']
      .mean()
      .reset_index()
)

pivot_table = pivot.pivot(index='item_category_id', columns='shop_size', values='revenue_month')

plt.figure(figsize=(10,8))
sns.heatmap(pivot_table, cmap='viridis')
plt.title('Revenue por categoría y tamaño de tienda')
plt.show()

# %% [markdown]
# Sanity check del target

# %%
y = monthly["item_cnt_month"]

print(y.describe(percentiles=[.5, .9, .95, .99]))
print("Mes-producto-tienda con 0 ventas:", (y == 0).mean().round(4))

# Histograma (clip al p99 para que se vea la forma sin que aplaste todo)
p99 = y.quantile(0.99)

plt.figure()
plt.hist(y.clip(upper=p99), bins=60)
plt.title("item_cnt_month (clip al p99 para ver forma)")
plt.xlabel("unidades por mes")
plt.ylabel("frecuencia")
plt.show()
# Out:
# count    1.608226e+06
# mean     2.273154e+00
# std      8.653235e+00
# min      1.000000e+00
# 50%      1.000000e+00
# 90%      4.000000e+00
# 95%      6.000000e+00
# 99%      1.700000e+01
# max      2.253000e+03
# Name: item_cnt_month, dtype: float64
# Mes-producto-tienda con 0 ventas: 0.0

# %% [markdown]
# Patrón temporal global (estacionalidad / cambios fuertes)

# %%
ts = monthly.groupby("date_block_num", as_index=False)["item_cnt_month"].sum()
ts["date_block_num"] = ts["date_block_num"].astype(int)

# 0 = 2013-01, 1 = 2013-02, ...
max_block = ts["date_block_num"].max()
month_map = pd.Series(
    pd.date_range("2013-01-01", periods=max_block + 1, freq="MS"),
    index=range(max_block + 1)
)

ts["month_dt"] = ts["date_block_num"].map(month_map)           # datetime64
ts["month"] = ts["month_dt"].dt.strftime("%Y-%m")              # etiqueta

plt.figure()
plt.plot(ts["month_dt"], ts["item_cnt_month"])
plt.title("Ventas mensuales totales (todas las tiendas y productos)")
plt.xlabel("Mes")
plt.ylabel("Unidades")

# etiqueta cada 3 meses para que no se encime
ticks = ts["month_dt"].iloc[::3]
plt.xticks(ticks, [d.strftime("%Y-%m") for d in ticks], rotation=45)

plt.tight_layout()
plt.show()

max_row = ts.loc[ts["item_cnt_month"].idxmax()]
min_row = ts.loc[ts["item_cnt_month"].idxmin()]

print("Mes con más unidades:", max_row["month"], "->", float(max_row["item_cnt_month"]))
print("Mes con menos unidades:", min_row["month"], "->", float(min_row["item_cnt_month"]))
# Out:
# Mes con más unidades: 2013-12 -> 183670.0
# Mes con menos unidades: 2015-07 -> 63316.0

# %% [markdown]
# ¿Quién carga el volumen? (top tiendas / top categorías)

# %%
top_shops = (
    monthly.groupby("shop_id")["item_cnt_month"].sum()
    .sort_values(ascending=False)
    .head(10)
)
print("Top 10 tiendas por unidades:")
print(top_shops)

top_cats = (
    monthly.groupby("item_category_id")["item_cnt_month"].sum()
    .sort_values(ascending=False)
    .head(10)
)
print("\nTop 10 categorías por unidades:")
print(top_cats)
# Out:
# Top 10 tiendas por unidades:
# shop_id
# 31    311230.0
# 25    242237.0
# 54    186149.0
# 28    184777.0
# 42    145195.0
# 57    141424.0
# 27    136815.0
# 6     100757.0
# 58     81908.0
# 46     79092.0
# Name: item_cnt_month, dtype: float32
#
# Top 10 categorías por unidades:
# item_category_id
# 40    634885.0
# 30    457359.0
# 55    349050.0
# 19    255756.0
# 37    204031.0
# 71    188016.0
# 28    175227.0
# 23    170577.0
# 20    127763.0
# 65     73103.0
# Name: item_cnt_month, dtype: float32

# %% [markdown]
# ver si el volumen está súper concentrado en pocos IDs

# %%
shop_share = top_shops.sum() / monthly["item_cnt_month"].sum()
cat_share = top_cats.sum() / monthly["item_cnt_month"].sum()

print("\n% de unidades explicadas por Top 10 tiendas:", round(shop_share * 100, 2), "%")
print("% de unidades explicadas por Top 10 categorías:", round(cat_share * 100, 2), "%")
# Out:
# % de unidades explicadas por Top 10 tiendas: 44.03 %
# % de unidades explicadas por Top 10 categorías: 72.1 %

# %% [markdown]
# Precio vs demanda

# %%
valid = monthly[monthly["item_price_mean"] > 0].copy()

# Si es enorme, muestreamos
sample = valid.sample(50000, random_state=42) if len(valid) > 50000 else valid

plt.figure()
plt.scatter(sample["item_price_mean"], sample["item_cnt_month"], s=5, alpha=0.3)
plt.title("Precio promedio mensual vs unidades mensuales (solo donde hubo precio > 0)")
plt.xlabel("item_price_mean")
plt.ylabel("item_cnt_month")
plt.show()

corr_spear = sample[["item_price_mean", "item_cnt_month"]].corr(method="spearman").iloc[0, 1]
print("Corr (Spearman) precio vs demanda:", round(float(corr_spear), 3))
# Out:
# Corr (Spearman) precio vs demanda: 0.158

# %% [markdown]
# Revisión rápida de cobertura vs test

# %%
train_pairs = monthly[["shop_id", "item_id"]].drop_duplicates()
test_pairs = test[["shop_id", "item_id"]].drop_duplicates()

covered = test_pairs.merge(train_pairs, on=["shop_id", "item_id"], how="left", indicator=True)
print("Pares en test:", len(test_pairs))
print("Pares vistos en train:", (covered["_merge"] == "both").sum())
print("Pares NO vistos en train:", (covered["_merge"] != "both").sum())
# Out:
# Pares en test: 214200
# Pares vistos en train: 111404
# Pares NO vistos en train: 102796
